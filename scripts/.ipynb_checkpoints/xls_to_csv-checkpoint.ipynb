# %% [markdown]
# # Skrypt wczytujacy dane .xls i zapisujacy je w formie csv
# (Wstępne czysczenie danych)

# %%
import pandas as pd


df = pd.read_excel("dane-zeliwo-ADI.xls",skiprows=12)

# %%
import pandas as pd

df = pd.read_excel("../data/Test SMAD.xlsx")

# %%
df.to_csv("test.csv")
# Out:
#    Nr źródła  C [%]  Si [%]  S [%]  P [%]  Mg [%]  Mn [%]  Ni [%]  Cu [%]  \
# 0        200   3.63    2.52  0.013  0.028  0.0043   0.162   0.024   0.215
# 1        200   3.63    2.52  0.013  0.028  0.0043   0.162   0.024   0.215
# 2        200   3.63    2.52  0.013  0.028  0.0043   0.162   0.024   0.215
# 3        200   3.63    2.52  0.013  0.028  0.0043   0.162   0.024   0.215
# 4        200   3.63    2.52  0.013  0.028  0.0043   0.162   0.024   0.215
# ..       ...    ...     ...    ...    ...     ...     ...     ...     ...
# 93      x001   3.36    3.54  0.008  0.033   0.057   0.280   0.000   0.227
# 94      x001   3.36    3.54  0.008  0.033   0.057   0.280   0.000   0.227
# 95      x001   3.40    3.74   0.01  0.039   0.063   0.260   0.000   0.220
# 96      x001   3.40    3.74   0.01  0.039   0.063   0.260   0.000   0.220
# 97      x001   3.40    3.74   0.01  0.039   0.063   0.260   0.000   0.220
#
#     Mo [%]  ...  Unnamed: 32  Rm [MPa]  R0,2 [MPa]  A5 [%]  \
# 0    0.002  ...          NaN     921.0         NaN     5.3
# 1    0.002  ...          NaN     847.0         NaN     6.1
# 2    0.002  ...          NaN     812.0         NaN     7.4
# 3    0.002  ...          NaN     772.0         NaN     8.4
# 4    0.002  ...          NaN     952.0         NaN     5.1
# ..     ...  ...          ...       ...         ...     ...
# 93   0.000  ...          NaN    1571.0         NaN     NaN
# 94   0.000  ...          NaN    1273.0         NaN     NaN
# 95   0.000  ...          NaN    1514.0         NaN     NaN
# 96   0.000  ...          NaN    1486.0         NaN     NaN
# 97   0.000  ...          NaN    1532.0         NaN     NaN
#
#     Twardość Brinella [HB]  Udarność Charpy [J]  \
# 0                    323.0                  NaN
# 1                    331.0                  NaN
# 2                    319.0                  NaN
# 3                    302.0                  NaN
# 4                    325.0                  NaN
# ..                     ...                  ...
# 93                     NaN                  NaN
# 94                     NaN                  NaN
# 95                     NaN                  NaN
# 96                     NaN                  NaN
# 97                     NaN                  NaN
#
#     Temperatura pomiaru udarności [˚C]  Martensite volume fraction Xα'  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ..                                 ...                             ...
# 93                                 NaN                             NaN
# 94                                 NaN                             NaN
# 95                                 NaN                             NaN
# 96                                 NaN                             NaN
# 97                                 NaN                             NaN
#
#     Udział austenitu szczątkowego XγR   Zawartość węgla w austenicie
# 0                                 17.6                           NaN
# 1                                 21.2                           NaN
# 2                                 25.4                           NaN
# 3                                 30.2                           NaN
# 4                                  NaN                           NaN
# ..                                 ...                           ...
# 93                                 NaN                           NaN
# 94                                 NaN                           NaN
# 95                                 NaN                           NaN
# 96                                 NaN                           NaN
# 97                                 NaN                           NaN
#
# [98 rows x 42 columns]

# %%
df = df.iloc[:,10:57]

# %%
kolumny = [df.columns.str.findall('Unnamed')[i] != ['Unnamed'] for i in range(df.shape[1])]

# %%
df = df.loc[:,kolumny]

# %%
df.to_csv('dane-zeliwo.csv')

# %%
df2 = pd.read_csv('dane-zeliwo.csv',sep = ',')

# %%
df2.head()
# Out:
#    Unnamed: 0 Nr źródła  C [%]  Si [%]  S [%]  P [%]  Mg [%]  Mn [%]  Ni [%]  \
# 0           0         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001
# 1           1         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001
# 2           2         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001
# 3           3         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001
# 4           4         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001
#
#    Cu [%]  ...  A5 [%]  Twardość Brinella [HB]  Twardość Rockwella [HRC]  \
# 0     0.0  ...     NaN                     NaN                       NaN
# 1     0.0  ...     NaN                     NaN                       NaN
# 2     0.0  ...    10.5                     NaN                       NaN
# 3     0.0  ...     9.6                     NaN                       NaN
# 4     0.0  ...     NaN                     NaN                       NaN
#
#    Twardość Rockwella [HRA]  Twardość Rockwella [HRB]  Twardość Vickersa [HV]  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
#
#    Udarność Charpy [J]  Temperatura pomiaru udarności [˚C]  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#    Udział austenitu % Martensite volume fraction Xα'
# 0                28.7                            NaN
# 1                37.5                            NaN
# 2                32.0                            NaN
# 3                28.5                            NaN
# 4                26.2                            NaN
#
# [5 rows x 42 columns]
